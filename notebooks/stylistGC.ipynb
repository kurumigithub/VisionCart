# %%
# test from gemini
# from google.colab import userdata # type: ignore

import os
import getpass
import torch
from dotenv import load_dotenv


# Run this cell; a text box will appear at the top of VS Code
if "HF_TOKEN" not in os.environ:
    os.environ["HF_TOKEN"] = getpass.getpass("Paste your HF_TOKEN here:")

if "SERPAPI_API_KEY" not in os.environ:
    os.environ["SERPAPI_API_KEY"] = getpass.getpass("Paste your SERPAPI_API_KEY here:")

print("Keys set for this remote session.")
# Out:
# Keys set for this remote session.

# %%
# 1. Check API Keys
load_dotenv()
print(f"HF_TOKEN present: {bool(os.environ.get('HF_TOKEN'))}")
print(f"SERPAPI_API_KEY present: {bool(os.environ.get('SERPAPI_API_KEY'))}")

# 2. Check GPU (Required for Stylist)
print(f"GPU Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Device: {torch.cuda.get_device_name(0)}")
# Out:
# HF_TOKEN present: True
# SERPAPI_API_KEY present: True
# GPU Available: True
# Device: NVIDIA A100-SXM4-40GB

# %%
from huggingface_hub import notebook_login, whoami
try:
    print(f"Authenticated as: {whoami()['name']}")
except Exception:
    print("Authentication failed. Check your token.")
# Out:
# Authenticated as: kskaneko
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(

# %%
# 1. Mount Google Drive
from google.colab import drive # type: ignore
import os
drive.mount('/content/drive')

# 2. Navigate to your project folder (Adjust path if necessary)
# %cd /content/drive/MyDrive/Coursework/Spring2026/INFO290/genai-final-project/VisionCart/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Coursework/Spring2026/INFO290/genai-final-project/VisionCart

# %%
# 3. Install GPU-specific dependencies
# Note: We use qwen-vl-utils for optimized image processing
# %pip install -q transformers accelerate qwen-vl-utils torchvision

# %%
import sys
import os

# Define your project root
PROJECT_ROOT = '/content/drive/MyDrive/Coursework/Spring2026/INFO290/genai-final-project/VisionCart/'

# Add it to the system path
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

# Verify you are in the right spot
# %cd {PROJECT_ROOT}
# Out:
# /content/drive/MyDrive/Coursework/Spring2026/INFO290/genai-final-project/VisionCart

# %%
# %run src/main-LC.py "https://www.pinterest.com/aesthetics/spring-wallpapers/"
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/729 [00:00<?, ?it/s]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# crawling pinterest board: https://www.pinterest.com/aesthetics/spring-wallpapers/
# images downloaded to: /content/drive/MyDrive/Coursework/Spring2026/INFO290/genai-final-project/VisionCart/data/2026-04-06_06-16-37
# stylist agent analysis
#
# --- RAW MODEL OUTPUT ---
# system
# You are a helpful assistant.
# user
# Analyze these images and create a 'Style Persona'.
#     Return ONLY a JSON object with these exact keys:
#     {
#       "style_profile": "A narrative prose describing the overall vibe.",
#       "products": ["List of specific item types to search for (e.g. 'planters')"],
#       "aesthetic": ["Mood descriptors (e.g. 'cottagecore', 'boho')"],
#       "colors": ["3-5 specific colors found in the images"],
#       "materials": ["3-5 materials (e.g. 'rattan', 'oak')"],
#       "budget_max": 100.0,
#       "budget_currency": "USD"
#     }
# assistant
# ```json
# {
#   "style_profile": "The style persona embodies a serene and nature-inspired aesthetic, blending elements of bohemian charm with a touch of mystical allure. The imagery evokes a sense of tranquility and connection to the outdoors, suggesting a lifestyle that values simplicity, natural beauty, and a spiritual connection to the environment. The presence of the butterfly and stars adds a whimsical and magical quality, hinting at a love for the fantastical and the ethereal.",
#   "products": ["wooden planters", "boho-style rugs", "star-shaped wall art", "butterfly-themed decor"],
#   "aesthetic": ["boho", "nature-inspired", "mystical"],
#   "colors": ["green", "blue", "brown", "white", "tan"],
#   "materials": ["wood", "textiles", "metal", "ceramic", "glass"],
#   "budget_max": 100.0,
#   "budget_currency": "USD"
# }
# ```
# ------------------------
#
# ✅ Corrected JSON string: {
#   "style_profile": "The style persona embodies a serene an...
# procurement agent search
# [procurement] Calling HuggingFace Inference API (model: Qwen/Qwen2.5-7B-Instruct)...
# [procurement] Query generation complete. Raw response: ["mystical glass star lantern boho nature", "wooden butterfly wall art nature inspired", "ceramic green tea set boho mystic", "handwoven blue textile throw mystical boho", "bronze nature inspired statue mystical charm"]
# [procurement] Fetching products for 5 queries (up to 20 results each)...
# [procurement]   [1/5] Querying SerpAPI: 'mystical glass star lantern boho nature'
# [procurement]          → 20 new products (pool total: 20)
# [procurement]   [2/5] Querying SerpAPI: 'wooden butterfly wall art nature inspired'
# [procurement]          → 20 new products (pool total: 40)
# [procurement]   [3/5] Querying SerpAPI: 'ceramic green tea set boho mystic'
# [procurement]          → 20 new products (pool total: 60)
# [procurement]   [4/5] Querying SerpAPI: 'handwoven blue textile throw mystical boho'
# [procurement]          → 20 new products (pool total: 80)
# [procurement]   [5/5] Querying SerpAPI: 'bronze nature inspired statue mystical charm'
# [procurement]          → 20 new products (pool total: 100)
# [procurement] Done. Total candidate pool: 100 products.
# ranker/critic evaluation
# output generation
#
# complete analysis
# Style Identified: The style persona embodies a serene and nature-inspired aesthetic, blending elements of bohemian charm with a touch of mystical allure. The imagery evokes a sense of tranquility and connection to the outdoors, suggesting a lifestyle that values simplicity, natural beauty, and a spiritual connection to the environment. The presence of the butterfly and stars adds a whimsical and magical quality, hinting at a love for the fantastical and the ethereal.
# Results: 0 products passed the critic.
# ------------------------------
# We couldn't find products that matched your style profile. Try adding more images to your board.

# %%
# import json
# import sys
# from datetime import datetime

# # add 'src' to path to import agent
# sys.path.append(os.path.abspath("src"))
# from agents import stylist

# def main():
#     # use latest crawled images
#     data_dir = "data"
#     subdirs = [os.path.join(data_dir, d) for d in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir, d))]
#     if not subdirs:
#         print("No crawled data found in data/ folder!")
#         return
    
#     latest_session = max(subdirs, key=os.path.getmtime)
#     print(f"Analyzing latest session: {latest_session}")

#     # collect all images from the latest crawl
#     image_paths = []
#     for root, dirs, files in os.walk(latest_session):
#         for file in files:
#             if file.lower().endswith(('.png', '.jpg', '.jpeg')):
#                 image_paths.append(os.path.join(root, file))

#     # prepare the State
#     state = {
#         "vision_board_paths": image_paths,
#         "num_products": 10
#     }

#     # execute stylist agent (Running on A100/L4 GPU)
#     print("Stylist is analyzing the vision board...")
#     result = stylist.run(state)
    
#     # save output for the Procurement Agent
#     output_path = "data/stylist_output.json"
#     with open(output_path, "w") as f:
#         json.dump(result["stylist_output"], f, indent=2)
    
#     print(f"success: style profile saved to {output_path}")
#     print(json.dumps(result["stylist_output"], indent=2))

# if __name__ == "__main__":
#     main()
